# %%
import reliability.reliability_field_maps as fm

# %%
import numpy as np
x = np.random.rand(10)
y = np.random.rand(10)

# %%
fm.plot_field_map(x,y,'red','Reds',0.5,True,False)
# Out:
# Creating a plot
# Creating l plot
# Creating l plot
# /Users/jaewook.cho/Documents/GitHub/reliability_fieldMap_gradientFlow/reliability/reliability_field_maps.py:57: UserWarning: linewidths is ignored by contourf
#   cset = contour_func(xx1, yy1, z1scale, n_levels, **kwargs)
# (array([[-2.62891924, -2.60820238, -2.58748553, ...,  3.5239864 ,
#           3.54470326,  3.56542011],
#         [-2.62891924, -2.60820238, -2.58748553, ...,  3.5239864 ,
#           3.54470326,  3.56542011],
#         [-2.62891924, -2.60820238, -2.58748553, ...,  3.5239864 ,
#           3.54470326,  3.56542011],
#         ...,
#         [-2.62891924, -2.60820238, -2.58748553, ...,  3.5239864 ,
#           3.54470326,  3.56542011],
#         [-2.62891924, -2.60820238, -2.58748553, ...,  3.5239864 ,
#           3.54470326,  3.56542011],
#         [-2.62891924, -2.60820238, -2.58748553, ...,  3.5239864 ,
#           3.54470326,  3.56542011]]),
#  array([[-1.88800571, -1.88800571, -1.88800571, ..., -1.88800571,
# ...
